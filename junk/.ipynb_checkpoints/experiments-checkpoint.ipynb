# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../work-data/train-data-cleaned.csv')

# %%
df
# Out:
#         Unnamed: 0         country  customer_id invoice  price  stream_id  \
# 0                0  United Kingdom      15581.0  493463   2.95      20895
# 1                1  United Kingdom      15581.0  493463   1.25      20866
# 2                2  United Kingdom      15581.0  493463   0.85      85198
# 3                3  United Kingdom      15581.0  493463   2.95      20897
# 4                4  United Kingdom      15581.0  493463   2.95      20898
# ...            ...             ...          ...     ...    ...        ...
# 810552       35050  United Kingdom      13269.0  548708   4.95      23184
# 810553       35051  United Kingdom      13269.0  548708   1.25      47310
# 810554       35052  United Kingdom      13269.0  548708   0.42      79190
# 810555       35053  United Kingdom      13269.0  548708   1.65      22859
# 810556       35054  United Kingdom      13269.0  548708   2.95      85123
#
#         times_viewed  year  month  day        date
# 0                  1  2018      1    1  2018-01-01
# 1                  1  2018      1    1  2018-01-01
# 2                 12  2018      1    1  2018-01-01
# 3                  1  2018      1    1  2018-01-01
# 4                  1  2018      1    1  2018-01-01
# ...              ...   ...    ...  ...         ...
# 810552             2  2019      3   31  2019-03-31
# 810553             1  2019      3   31  2019-03-31
# 810554             9  2019      3   31  2019-03-31
# 810555             1  2019      3   31  2019-03-31
# 810556             3  2019      3   31  2019-03-31
#
# [810557 rows x 11 columns]

# %%
date_type='datetime64[D]'

# %%
mindate=df['date'].values.astype(date_type).min()
maxdate=df['date'].values.astype(date_type).max()

# %%
dates_range=np.arange(mindate,maxdate,dtype=date_type)
date_indices=df.date.values.astype(date_type)

# %%
ts_columns=['date','purchases','invoices','streams','views','revenue','year_month']

invoices=[np.unique(df[date_indices==day]['invoice']).size for day in dates_range]
streams=[np.unique(df[date_indices==day]['stream_id']).size for day in dates_range]
purchases=[df[date_indices==day].shape[0] for day in dates_range]
views=[(df[date_indices==day]['times_viewed']).values.sum() for day in dates_range]
revenues=[(df[date_indices==day]['price']).values.sum() for day in dates_range]
year_months=year_month = ["-".join(re.split("-",str(day))[:2]) for day in dates_range]

# %%
dates_range
# Out:
# array(['2017-11-28', '2017-11-29', '2017-11-30', '2017-12-01',
#        '2017-12-02', '2017-12-03', '2017-12-04', '2017-12-05',
#        '2017-12-06', '2017-12-07', '2017-12-08', '2017-12-09',
#        '2017-12-10', '2017-12-11', '2017-12-12', '2017-12-13',
#        '2017-12-14', '2017-12-15', '2017-12-16', '2017-12-17',
#        '2017-12-18', '2017-12-19', '2017-12-20', '2017-12-21',
#        '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#        '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#        '2017-12-30', '2017-12-31', '2018-01-01', '2018-01-02',
#        '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-06',
#        '2018-01-07', '2018-01-08', '2018-01-09', '2018-01-10',
#        '2018-01-11', '2018-01-12', '2018-01-13', '2018-01-14',
#        '2018-01-15', '2018-01-16', '2018-01-17', '2018-01-18',
#        '2018-01-19', '2018-01-20', '2018-01-21', '2018-01-22',
#        '2018-01-23', '2018-01-24', '2018-01-25', '2018-01-26',
#        '2018-01-27', '2018-01-28', '2018-01-29', '2018-01-30',
#        '2018-01-31', '2018-02-01', '2018-02-02', '2018-02-03',
#        '2018-02-04', '2018-02-05', '2018-02-06', '2018-02-07',
#        '2018-02-08', '2018-02-09', '2018-02-10', '2018-02-11',
#        '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22',
#        '2019-02-23', '2019-02-24', '2019-02-25', '2019-02-26',
#        '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-02',
#        '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06',
#        '2019-03-07', '2019-03-08', '2019-03-09', '2019-03-10',
#        '2019-03-11', '2019-03-12', '2019-03-13', '2019-03-14',
#        '2019-03-15', '2019-03-16', '2019-03-17', '2019-03-18',
#        '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22',
#        '2019-03-23', '2019-03-24', '2019-03-25', '2019-03-26',
#        '2019-03-27', '2019-03-28', '2019-03-29', '2019-03-30',
#        '2019-03-31', '2019-04-01', '2019-04-02', '2019-04-03',
#        '2019-04-04', '2019-04-05', '2019-04-06', '2019-04-07',
#        '2019-04-08', '2019-04-09', '2019-04-10', '2019-04-11',
#        '2019-04-12', '2019-04-13', '2019-04-14', '2019-04-15',
#        '2019-04-16', '2019-04-17', '2019-04-18', '2019-04-19',
#        '2019-04-20', '2019-04-21', '2019-04-22', '2019-04-23',
#        '2019-04-24', '2019-04-25', '2019-04-26', '2019-04-27',
#        '2019-04-28', '2019-04-29', '2019-04-30', '2019-05-01',
#        '2019-05-02', '2019-05-03', '2019-05-04', '2019-05-05',
#        '2019-05-06', '2019-05-07', '2019-05-08', '2019-05-09',
#        '2019-05-10', '2019-05-11', '2019-05-12', '2019-05-13',
#        '2019-05-14', '2019-05-15', '2019-05-16', '2019-05-17',
#        '2019-05-18', '2019-05-19', '2019-05-20', '2019-05-21',
#        '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-25',
#        '2019-05-26', '2019-05-27', '2019-05-28', '2019-05-29',
#        '2019-05-30', '2019-05-31', '2019-06-01', '2019-06-02',
#        '2019-06-03', '2019-06-04', '2019-06-05', '2019-06-06',
#        '2019-06-07', '2019-06-08', '2019-06-09', '2019-06-10',
#        '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14',
#        '2019-06-15', '2019-06-16', '2019-06-17', '2019-06-18',
#        '2019-06-19', '2019-06-20', '2019-06-21', '2019-06-22',
#        '2019-06-23', '2019-06-24', '2019-06-25', '2019-06-26',
#        '2019-06-27', '2019-06-28', '2019-06-29', '2019-06-30',
#        '2019-07-01', '2019-07-02', '2019-07-03', '2019-07-04',
#        '2019-07-05', '2019-07-06', '2019-07-07', '2019-07-08',
#        '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-12',
#        '2019-07-13', '2019-07-14', '2019-07-15', '2019-07-16',
#        '2019-07-17', '2019-07-18', '2019-07-19', '2019-07-20',
#        '2019-07-21', '2019-07-22', '2019-07-23', '2019-07-24',
#        '2019-07-25', '2019-07-26', '2019-07-27', '2019-07-28',
#        '2019-07-29', '2019-07-30'], dtype='datetime64[D]')

# %%
by_revenue=df[['country','price']].groupby('country').sum()

# %%
by_revenue.sort_values('price',ascending=False).iloc[0:10,:].index.values
# Out:
# array(['United Kingdom', 'EIRE', 'Germany', 'France', 'Netherlands',
#        'Spain', 'Switzerland', 'Belgium', 'Channel Islands', 'Portugal'],
#       dtype=object)

# %%
p10=pd.read_json('../data/cs-train/invoices-2018-10.json')

# %%
p10
# Out:
#               country  customer_id invoice  price stream_id  times_viewed  \
# 0      United Kingdom      14506.0  569524   1.25     21894             1
# 1      United Kingdom      14506.0  569524   1.25     22477             1
# 2      United Kingdom      14506.0  569524   3.75     23393             1
# 3      United Kingdom      14506.0  569524   3.75     23396             1
# 4      United Kingdom      14506.0  569524   0.39     22944             6
# ...               ...          ...     ...    ...       ...           ...
# 63849  United Kingdom      16347.0  574249   4.25    84029E             3
# 63850  United Kingdom      16347.0  574249   4.25     21479             3
# 63851  United Kingdom      16347.0  574249   4.95     23355             4
# 63852  United Kingdom      16347.0  574249   4.95     21485             1
# 63853  United Kingdom      16347.0  574249   1.25     23502             6
#
#        year  month  day
# 0      2019     10    1
# 1      2019     10    1
# 2      2019     10    1
# 3      2019     10    1
# 4      2019     10    1
# ...     ...    ...  ...
# 63849  2019     10   31
# 63850  2019     10   31
# 63851  2019     10   31
# 63852  2019     10   31
# 63853  2019     10   31
#
# [63854 rows x 9 columns]

# %%
ct10=p10[['country','price']].groupby('country').sum()

# %%
ct10
# Out:
#                           price
# country
# Australia                427.16
# Austria                  141.50
# Bahrain                   38.78
# Belgium                  387.89
# Canada                    80.12
# Channel Islands          752.42
# Cyprus                   109.04
# Denmark                  118.78
# EIRE                   20010.97
# Finland                  103.90
# France                  1968.79
# Germany                 3264.75
# Greece                   668.83
# Iceland                   73.36
# Italy                   1322.62
# Japan                     21.34
# Korea                     30.08
# Lebanon                   39.67
# Netherlands              754.57
# Norway                    65.76
# Portugal                 556.99
# RSA                     2956.29
# Spain                    839.08
# Sweden                   695.59
# Switzerland              874.64
# USA                       14.56
# United Arab Emirates      26.30
# United Kingdom        243017.00

# %%
from datetime import date,time,datetime


date.today()

datetime.now()
# Out:
# datetime.datetime(2020, 11, 30, 15, 58, 36, 159271)

# %%
ukts=pd.read_csv('../data/work-data/ts-data-united_kingdom.csv')

# %%
ukts
# Out:
#      Unnamed: 0        date  invoices  streams  purchases  views  revenues  \
# 0             0  2017-11-28       152     1152       2936  12905  11830.82
# 1             1  2017-11-29       124     1257       3213  13647  11907.92
# 2             2  2017-11-30       142     1187       2907  15236  10071.40
# 3             3  2017-12-01        98     1101       2438  11646   8212.99
# 4             4  2017-12-02        31      243        370   3101   1263.28
# ..          ...         ...       ...      ...        ...    ...       ...
# 605         605  2019-07-26        67      631       1054   6907   3189.30
# 606         606  2019-07-27         0        0          0      0      0.00
# 607         607  2019-07-28        38      697       1090   5217   2651.59
# 608         608  2019-07-29        48      703       1121   6321   3731.88
# 609         609  2019-07-30        50      678       1001   5482   3673.06
#
#     year_month
# 0      2017-11
# 1      2017-11
# 2      2017-11
# 3      2017-12
# 4      2017-12
# ..         ...
# 605    2019-07
# 606    2019-07
# 607    2019-07
# 608    2019-07
# 609    2019-07
#
# [610 rows x 8 columns]

# %%
(ukts[['invoices','streams','purchases','revenues']]
 .style
 .hide_index()
 .bar(color='lightblue', vmin=0, subset=['invoices'], align='zero')
 .bar(color='lightblue', vmin=0, subset=['streams'], align='zero')
 .bar(color='red', vmin=0, vmax=0.1, subset=['purchases'], align='zero')
 .bar(color='red', vmin=0, vmax=0.1, subset=['revenues'], align='zero')
 .set_caption('Performance Monitoring'))
