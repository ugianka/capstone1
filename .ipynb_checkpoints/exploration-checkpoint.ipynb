# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import math

# %%
data_path='./cs-train'
onlyfiles = [join(data_path, f) for f in listdir(data_path) if isfile(join(data_path, f))]

# %%
inpDf=pd.DataFrame()

# %%
for idx,fname in enumerate(onlyfiles):
    inpDf= inpDf.append(pd.read_json(fname))
# Out:
# /Users/ugianka/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
inpDf
# Out:
#       StreamID  TimesViewed         country  customer_id  day invoice  month  \
# 0          NaN          NaN  United Kingdom      13162.0    1  490297     12
# 1          NaN          NaN  United Kingdom      13162.0    1  490297     12
# 2          NaN          NaN  United Kingdom      13162.0    1  490297     12
# 3          NaN          NaN  United Kingdom      13162.0    1  490297     12
# 4          NaN          NaN  United Kingdom      13162.0    1  490297     12
# ...        ...          ...             ...          ...  ...     ...    ...
# 35050      NaN          NaN  United Kingdom      13269.0   31  548708      3
# 35051      NaN          NaN  United Kingdom      13269.0   31  548708      3
# 35052      NaN          NaN  United Kingdom      13269.0   31  548708      3
# 35053      NaN          NaN  United Kingdom      13269.0   31  548708      3
# 35054      NaN          NaN  United Kingdom      13269.0   31  548708      3
#
# ...

# %%
#clean the dataFrame by unifyng the columns move data from StreamID and TimesViewed to stream_id and times_viewed

cleanedDf=pd.DataFrame()
for idx,row in inpDf.iterrows():
    bogusStream=row['StreamID']
    bogusTimesViewed=row['TimesViewed']
    
    # check is StreamID is not NaN
    if(bogusStream==bogusStream): 
        row['stream_id']=row['StreamID']
     # check is TimesViewed is not NaN
    if(bogusTimesViewed==bogusTimesViewed):
        row['times_viewed']=row['TimesViewed']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-c2b460990736> in <module>
#       1 cleanedDf=pd.DataFrame()
#       2 for idx,row in inpDf.iterrows():
# ----> 3     if(math.isnan(row['StreamID'])):
#       4         print(row)
#
# TypeError: must be real number, not str
